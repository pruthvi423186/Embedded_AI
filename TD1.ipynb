# %%
from google.colab import drive
from os.path import join

ROOT = '/content/drive'     # default for the drive
PROJ = 'MyDrive/MyProjetc'  # path to your project on Drive

drive.mount(ROOT)           # mount the drive at /content/drive

PROJECT_PATH = join(ROOT, PROJ)
# !mkdir -p "{PROJECT_PATH}"   # create the directory if it doesn't exist
# %cd "{PROJECT_PATH}"

GIT_USERNAME = "pruthvi423186"
GIT_TOKEN = "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"
GIT_REPOSITORY = "Embedded_AI"
GIT_PATH = "https://github.com/pruthvi423186/Embedded_AI.git"

# !git clone "{GIT_PATH}"
# %cd "{GIT_REPOSITORY}"

# Ensure the 'generated' directory exists in the cloned repository
# !mkdir -p generated

# Now run the rsync command
# !rsync -aP --exclude="data/" "generated/" .

# Verify the contents of the cloned repository
# !ls -l
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/MyProjetc
# fatal: destination path 'Embedded_AI' already exists and is not an empty directory.
# /content/drive/MyDrive/MyProjetc/Embedded_AI
# sending incremental file list
# total 4
# drwx------ 2 root root 4096 Jan 17 15:44 generated

# %%
# !ls
# Out:
# generated

# %%
# !git add .
# !git commit -m "Put here a message that describes your modifications. e.g. answering question 3"
# !git config --global user.email "your github email"
# !git config --global user.name "your first and last name"
# !git push origin master

# %%
x = 1

# %%
x
# Out:
# 1

# %%
y = 2

# %%
y
# Out:
# 2

# %%
print (x+y)
# Out:
# 3

# %%
text = "python is a good language"

# %%
text
# Out:
# 'python is a good language'

# %%
print(text)
# Out:
# python is a good language

# %%
print(str(x)+text+str(y))
# Out:
# 1python is a good language2

# %%
print("The variable x has a value of {} and y a value of {}".format(x, y))
# Out:
# The variable x has a value of 1 and y a value of 2

# %%
pi = 3.1416

# %%
print("Pi has an approximate value of {:.2f}".format(pi))
# Out:
# Pi has an approximate value of 3.14

# %%
liste = [1, 2, 3, 4, 5]

# %%
liste
# Out:
# [1, 2, 3, 4, 5]

# %%
print(type(liste))
print(type(text))
print(type(x))
print(type(pi))
# Out:
# <class 'list'>
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
int(pi)
# Out:
# 3

# %%
pi
# Out:
# 3.1416

# %%
# converting to integer, change the variable value
pi = int(pi)
pi
# Out:
# 3

# %%
# converting back to float does not return with original value
float(pi)
# Out:
# 3.0

# %%
print(min(liste))
print(max(liste))
# Out:
# 1
# 5

# %%
len(liste)
# Out:
# 5

# %%
lst = list(('a', 'b', 'c', 1, 2, 3))
lst
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
lst.append(3)
lst
# Out:
# ['a', 'b', 'c', 1, 2, 3, 3]

# %%
# set takes only unique values (ordering values)
set(lst)
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
# original lst does not changed (to change it, do: lst = set(lst))
lst
# Out:
# ['a', 'b', 'c', 1, 2, 3, 3]

# %%
liste.append(0)
liste.sort()
liste
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
# Out:
#   File "<ipython-input-61-a66875e53aa7>", line 1
#     echo "# Embedded_AI" >> README.md
#          ^
# SyntaxError: invalid syntax

# %%
liste.pop(0)
liste
# Out:
# [1, 2, 3, 4, 5]

# %%
lst
# Out:
# ['a', 'b', 'c', 1, 2, 3, 3]

# %%
lst.index(3)
# Out:
# 5

# %%
lst.insert(3,'d')

# %%
lst
# Out:
# ['a', 'b', 'c', 'd', 1, 2, 3, 3]
